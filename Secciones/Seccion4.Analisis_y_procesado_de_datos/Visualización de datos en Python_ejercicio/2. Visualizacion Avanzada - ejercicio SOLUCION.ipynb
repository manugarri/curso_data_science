# %% [markdown]
# Tenemos un dataset llamado `datos_misteriosos.csv` y queremos usar la visualización de datos para responder las siguientes preguntas:

# %%
# %matplotlib notebook

# %% [markdown]
# ## ¿Cómo es la distribución de `x` en general?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/datos_misteriosos.csv")

# %%
df.head()
# Out:
#     clase        x        y
# 0  clase1  55.3846  97.1795
# 1  clase1  51.5385  96.0256
# 2  clase1  46.1538  94.4872
# 3  clase1  42.8205  91.4103
# 4  clase1  40.7692  88.3333

# %% [markdown]
# ## ¿Hay algún valor extremo en cualquiera de las columnas?

# %%
df.boxplot(["x", "y"]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Elegir los 2 gráficos que mejor representan los datos. Cambia su estilo a `bmh` y añade un título a cada gráfica explicando lo que representa

# %%
import matplotlib.pyplot as plt

# %%
df.clase.unique()
# Out:
# array(['clase1', 'clase2'], dtype=object)

# %%
plt.style.use("bmh")

# %%
df[df.clase=="clase2"].plot.scatter(x="x", y="y")
plt.title("Estrella");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df[df.clase=="clase1"].plot.scatter(x="x", y="y")
plt.title("dinosaurio");
# Out:
# <img src="data:image/png;base64,..." width="640">
